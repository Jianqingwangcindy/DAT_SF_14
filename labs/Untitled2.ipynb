# %%
import pandas as pd

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
print d
cities = pd.Series(d)
print cities
# Out:
# {'Chicago': 1000, 'Boston': None, 'New York': 1300, 'San Francisco': 1100, 'Portland': 900, 'Austin': 450}
# Austin            450
# Boston            NaN
# Chicago          1000
# New York         1300
# Portland          900
# San Francisco    1100
# dtype: float64

# %%
print cities['Portland']
# Out:
# 900.0

# %%
print d['Portland']
# Out:
# 900

# %%
type(d)
type(cities)
# Out:
# pandas.core.series.Series

# %%
type(d)
# Out:
# dict

# %%
cities[cities < 950]
# Out:
# Austin      450
# Portland    900
# dtype: float64

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
print data
print type(data)
print football
print type(football)
# Out:
# {'losses': [5, 8, 6, 1, 5, 10, 6, 12], 'wins': [11, 8, 10, 15, 11, 6, 10, 4], 'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'], 'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012]}
# <type 'dict'>
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12
# <class 'pandas.core.frame.DataFrame'>

# %%
cols = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
        'marital_status', 'occupation', 'relationship', 'ethnicity',
        'gender', 'capital_gain', 'capital_loss', 'hours_per_week',
        'country_of_origin', 'income']
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',sep=',',  header=None, names = cols)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# ...

# %%
df
# Out:
#        0                  1       2              3   4   \
# 0      39          State-gov   77516      Bachelors  13
# 1      50   Self-emp-not-inc   83311      Bachelors  13
# 2      38            Private  215646        HS-grad   9
# 3      53            Private  234721           11th   7
# 4      28            Private  338409      Bachelors  13
# 5      37            Private  284582        Masters  14
# 6      49            Private  160187            9th   5
# 7      52   Self-emp-not-inc  209642        HS-grad   9
# 8      31            Private   45781        Masters  14
# 9      42            Private  159449      Bachelors  13
# 10     37            Private  280464   Some-college  10
# 11     30          State-gov  141297      Bachelors  13
# 12     23            Private  122272      Bachelors  13
# 13     32            Private  205019     Assoc-acdm  12
# 14     40            Private  121772      Assoc-voc  11
# 15     34            Private  245487        7th-8th   4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# 0     32561 non-null int64
# 1     32561 non-null object
# 2     32561 non-null int64
# 3     32561 non-null object
# 4     32561 non-null int64
# 5     32561 non-null object
# 6     32561 non-null object
# 7     32561 non-null object
# 8     32561 non-null object
# 9     32561 non-null object
# 10    32561 non-null int64
# 11    32561 non-null int64
# 12    32561 non-null int64
# 13    32561 non-null object
# 14    32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df.dtypes
# Out:
# 0      int64
# 1     object
# 2      int64
# 3     object
# 4      int64
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10     int64
# 11     int64
# 12     int64
# 13    object
# 14    object
# dtype: object

# %%
df.dtypes
# Out:
# age                   int64
# workclass            object
# fnlwgt                int64
# education            object
# education_num         int64
# marital_status       object
# occupation           object
# relationship         object
# ethnicity            object
# gender               object
# capital_gain          int64
# capital_loss          int64
# hours_per_week        int64
# country_of_origin    object
# income               object
# dtype: object

# %%
df.describe()
# Out:
#                 age          fnlwgt  education_num  capital_gain  \
# count  32561.000000    32561.000000   32561.000000  32561.000000
# mean      38.581647   189778.366512      10.080679   1077.648844
# std       13.640433   105549.977697       2.572720   7385.292085
# min       17.000000    12285.000000       1.000000      0.000000
# 25%       28.000000   117827.000000       9.000000      0.000000
# 50%       37.000000   178356.000000      10.000000      0.000000
# 75%       48.000000   237051.000000      12.000000      0.000000
# max       90.000000  1484705.000000      16.000000  99999.000000
#
#        capital_loss  hours_per_week
# count  32561.000000    32561.000000
# mean      87.303830       40.437456
# std      402.960219       12.347429
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# ...

# %%
df[10:20]
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
# 15   34            Private  245487        7th-8th              4
# 16   25   Self-emp-not-inc  176756        HS-grad              9
# 17   32            Private  186824        HS-grad              9
# 18   38            Private   28887           11th              7
# 19   43   Self-emp-not-inc  292175        Masters             14
#
#          marital_status          occupation    relationship  \
# 10   Married-civ-spouse     Exec-managerial         Husband
# 11   Married-civ-spouse      Prof-specialty         Husband
# 12        Never-married        Adm-clerical       Own-child
# ...

# %%
df['age'].dtypes
# Out:
# dtype('int64')

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['age'][2])
# Out:
# numpy.int64

# %%
type(df[['age','education']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['age','education']][2:])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.age)
# Out:
# pandas.core.series.Series

# %%
df.age[3]
# Out:
# 53

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# ...

# %%
df.ix[1:2]
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
#
#         marital_status          occupation    relationship ethnicity gender  \
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# 1             0             0              13     United-States   <=50K
# 2             0             0              40     United-States   <=50K

# %%
df[1:2]
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital_status        occupation relationship ethnicity gender  \
# 1   Married-civ-spouse   Exec-managerial      Husband     White   Male
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# 1             0             0              13     United-States   <=50K

# %%
type(df.groupby('workclass'))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
df.groupby('workclass').count().head(3)
# Out:
#                age  fnlwgt  education  education_num  marital_status  \
# workclass
#  ?            1836    1836       1836           1836            1836
#  Federal-gov   960     960        960            960             960
#  Local-gov    2093    2093       2093           2093            2093
#
#               occupation  relationship  ethnicity  gender  capital_gain  \
# workclass
#  ?                  1836          1836       1836    1836          1836
#  Federal-gov         960           960        960     960           960
#  Local-gov          2093          2093       2093    2093          2093
#
#               capital_loss  hours_per_week  country_of_origin  income
# workclass
#  ?                    1836            1836               1836    1836
#  Federal-gov           960             960                960     960
#  Local-gov            2093            2093               2093    2093

# %%
df.groupby('workclass').size().head(3)
# Out:
# workclass
#  ?              1836
#  Federal-gov     960
#  Local-gov      2093
# dtype: int64

# %%
type(df.groupby('workclass').size())
# Out:
# pandas.core.series.Series

# %%
type(df.groupby('workclass').mean())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('workclass').mean()
# Out:
#                          age         fnlwgt  education_num  capital_gain  \
# workclass
#  ?                 40.960240  188516.338235       9.260349    606.795752
#  Federal-gov       42.590625  185221.243750      10.973958    833.232292
#  Local-gov         41.751075  188639.712852      11.042045    880.202580
#  Never-worked      20.571429  225989.571429       7.428571      0.000000
#  Private           36.797585  192764.114734       9.879714    889.217792
#  Self-emp-inc      46.017025  175981.344086      11.137097   4875.693548
#  Self-emp-not-inc  44.969697  175608.641480      10.226289   1886.061787
#  State-gov         39.436055  184136.613251      11.375963    701.699538
#  Without-pay       47.785714  174267.500000       9.071429    487.857143
#
#                    capital_loss  hours_per_week
# workclass
#  ?                    60.760349       31.919390
#  Federal-gov         112.268750       41.379167
#  Local-gov           109.854276       40.982800
# ...

# %%
df.groupby('workclass').mean().age
# Out:
# workclass
#  ?                   40.960240
#  Federal-gov         42.590625
#  Local-gov           41.751075
#  Never-worked        20.571429
#  Private             36.797585
#  Self-emp-inc        46.017025
#  Self-emp-not-inc    44.969697
#  State-gov           39.436055
#  Without-pay         47.785714
# Name: age, dtype: float64

# %%
df.groupby('workclass').age.mean()
# Out:
# workclass
#  ?                   40.960240
#  Federal-gov         42.590625
#  Local-gov           41.751075
#  Never-worked        20.571429
#  Private             36.797585
#  Self-emp-inc        46.017025
#  Self-emp-not-inc    44.969697
#  State-gov           39.436055
#  Without-pay         47.785714
# Name: age, dtype: float64

# %%
type(df.groupby('workclass'))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
df.groupby('workclass').age.unique()
# Out:
# workclass
#  ?                   [54, 32, 25, 67, 17, 35, 43, 52, 68, 53, 19, 6...
#  Federal-gov         [35, 30, 57, 50, 43, 32, 38, 39, 37, 41, 40, 2...
#  Local-gov           [56, 23, 31, 49, 34, 29, 47, 66, 44, 41, 42, 5...
#  Never-worked                                     [18, 23, 17, 20, 30]
#  Private             [38, 53, 28, 37, 49, 31, 42, 23, 32, 40, 34, 5...
#  Self-emp-inc        [47, 49, 32, 56, 61, 44, 58, 54, 37, 41, 52, 6...
#  Self-emp-not-inc    [50, 52, 25, 43, 48, 53, 29, 47, 56, 38, 71, 4...
#  State-gov           [39, 30, 22, 41, 29, 46, 28, 58, 37, 59, 40, 2...
#  Without-pay              [65, 19, 21, 22, 46, 52, 62, 29, 72, 68, 67]
# Name: age, dtype: object

# %%
type(df.groupby('workclass').age.unique())
# Out:
# pandas.core.series.Series

# %%
df.groupby('workclass').age.unique()[0]
# Out:
# array([54, 32, 25, 67, 17, 35, 43, 52, 68, 53, 19, 64, 60, 20, 39, 23, 30,
#        59, 28, 80, 22, 63, 72, 57, 21, 34, 18, 65, 42, 55, 58, 70, 66, 45,
#        50, 48, 27, 36, 76, 24, 51, 33, 69, 62, 61, 75, 49, 26, 31, 29, 47,
#        74, 40, 56, 46, 82, 79, 83, 77, 37, 90, 73, 38, 78, 41, 71, 81, 44,
#        84, 87], dtype=int64)

# %%
df.groupby('workclass').age.unique()['Private']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-854bc1546029> in <module>()
# ----> 1 df.groupby('workclass').age.unique()['Private']
#
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     507     def __getitem__(self, key):
#     508         try:
# --> 509             result = self.index.get_value(self, key)
#     510
#     511             if not np.isscalar(result):
#
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\index.pyc in get_value(self, series, key)
#    1429                     raise InvalidIndexError(key)
#    1430                 else:
# -> 1431                     raise e1
#    1432             except Exception:  # pragma: no cover
#    1433                 raise e1
#
# KeyError: 'Private'

# %%
df.groupby('workclass').age.nunique()
# Out:
# workclass
#  ?                   70
#  Federal-gov         61
#  Local-gov           65
#  Never-worked         5
#  Private             72
#  Self-emp-inc        67
#  Self-emp-not-inc    71
#  State-gov           59
#  Without-pay         11
# Name: age, dtype: int64

# %%
df.age.nunique()
# Out:
# 73

# %%
type(df.age.nunique())
# Out:
# int

# %%
df.groupby('workclass').age.nunique().order(ascending=False)
# Out:
# workclass
#  Private             72
#  Self-emp-not-inc    71
#  ?                   70
#  Self-emp-inc        67
#  Local-gov           65
#  Federal-gov         61
#  State-gov           59
#  Without-pay         11
#  Never-worked         5
# Name: age, dtype: int64
