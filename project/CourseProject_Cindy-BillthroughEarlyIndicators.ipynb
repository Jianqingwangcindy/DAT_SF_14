# %%
import sys 
import os 
import string as s 
import json 
from sqlalchemy import * 
import numpy as np

from datetime import * 
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# original dataset
#df = pd.read_csv('C:\Users\cwang\Documents\Training\DataScience\Project\ProjectRawData.csv')

# the one removed with high covariance variable
df = pd.read_csv('C:\Users\cwang\Documents\Training\DataScience\Project\ProjectRawDataCleanUp.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63807 entries, 0 to 63806
# Data columns (total 63 columns):
# netbillthroughquantity                 63807 non-null int64
# regtype                                63807 non-null object
# signupsubscription                     63807 non-null object
# entrypage                              63807 non-null object
# device                                 63807 non-null object
# firstactivity24houraftersignup         63807 non-null object
# firstactivity2houraftersignup          63807 non-null object
# lastofferpage                          63807 non-null object
# sessioncount24                         63807 non-null int64
# sessioncount2hr                        63807 non-null int64
# firstsessionlength                     63807 non-null int64
# secondsessionlength                    63807 non-null int64
# createtreebeforesignup                 63807 non-null int64
# searchvolumebeforesignup               63807 non-null int64
# contentviewimagebeforesignup           63807 non-null int64
# contentviewimagedbbeforesignup         63807 non-null int64
# contentviewtextbeforesignup            63807 non-null int64
# contentviewtextdbbeforesignup          63807 non-null int64
# contentviewhoverbeforesignup           63807 non-null int64
# contentviewhoverdbbeforesignup         63807 non-null int64
# contentviewhovernosubbeforesignup      63807 non-null int64
# contentviewhovernosubdbbeforesignup    63807 non-null int64
# grosstreecountatsignup                 63807 non-null int64
# nettreecountatsignup                   63807 non-null int64
# netnodescountatsignup                  63807 non-null int64
# totalpendinghintscountatsignup         63807 non-null int64
# createtreein2hours                     63807 non-null int64
# netnodesgrowthin2hours                 63807 non-null int64
# personahintsgeneratedcount             63807 non-null int64
# personahintacteduponcount              63807 non-null int64
# personahintacceptedcount               63807 non-null int64
# acceptpersonahintsnodescount           63807 non-null int64
# objecthintsgeneratedcount              63807 non-null int64
# objecthintacteduponcount               63807 non-null int64
# objecthintacceptedcount                63807 non-null int64
# acceptobjecthintsnodescount            63807 non-null int64
# recordhintsgeneratedcount              63807 non-null int64
# recordhintacteduponcount               63807 non-null int64
# recordhintacceptedcount                63807 non-null int64
# acceptrecordhintsnodescount            63807 non-null int64
# acceptrecordhintsrecordcount           63807 non-null int64
# acceptrecordhintsdbidcount             63807 non-null int64
# searchcountin2hours                    63807 non-null int64
# searchdbcountin2hours                  63807 non-null int64
# contentviewcountin2hours               63807 non-null int64
# contentviewdbcountin2hours             63807 non-null int64
# contentimageviewcountin2hours          63807 non-null int64
# contentimageviewdbcountin2hours        63807 non-null int64
# familytreeviewin2hours                 63807 non-null int64
# pedigreetreeviewin2hours               63807 non-null int64
# totaltreeviewin2hours                  63807 non-null int64
# personoverviewin2hours                 63807 non-null int64
# personoverviewtreesin2hours            63807 non-null int64
# personoverviewnodesin2hours            63807 non-null int64
# dbcitationcountin2hours                63807 non-null int64
# hintsdbcitationcountin2hours           63807 non-null int64
# searchdbcitationcountin2hours          63807 non-null int64
# dbcitationnodescountin2hours           63807 non-null int64
# dbcitationdatabasecountin2hours        63807 non-null int64
# createnodesfromhintsin2hours           63807 non-null int64
# createnodesfromsearchin2hours          63807 non-null int64
# createnodesfromotherin2hours           63807 non-null int64
# age                                    63807 non-null int64
# dtypes: int64(56), object(7)
# memory usage: 31.2+ MB

# %%
df.describe()
# Out:
#        netbillthroughquantity  sessioncount24  sessioncount2hr  \
# count            63807.000000    63807.000000     63807.000000
# mean                 0.414108        1.767580         1.019684
# std                  0.492571        1.443908         0.443273
# min                  0.000000        0.000000         0.000000
# 25%                  0.000000        1.000000         1.000000
# 50%                  0.000000        1.000000         1.000000
# 75%                  1.000000        2.000000         1.000000
# max                  1.000000       14.000000         4.000000
#
#        firstsessionlength  secondsessionlength  createtreebeforesignup  \
# count        63807.000000         63807.000000            63807.000000
# mean            52.187268            17.673907                0.196859
# std             68.669634            46.106396                0.397628
# min             -1.000000            -1.000000                0.000000
# 25%             10.000000             0.000000                0.000000
# 50%             29.000000             0.000000                0.000000
# 75%             68.000000            11.000000                0.000000
# max            952.000000          1008.000000                1.000000
#
#        searchvolumebeforesignup  contentviewimagebeforesignup  \
# count              63807.000000                  63807.000000
# mean                   0.056875                      0.078424
# std                    0.231605                      0.913059
# min                    0.000000                      0.000000
# 25%                    0.000000                      0.000000
# 50%                    0.000000                      0.000000
# 75%                    0.000000                      0.000000
# max                    1.000000                    110.000000
#
#        contentviewimagedbbeforesignup  contentviewtextbeforesignup  \
# count                    63807.000000                 63807.000000
# mean                         0.046938                     0.132415
# std                          0.232544                     1.346709
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     0.000000
# max                          4.000000                    96.000000
#
#            ...       personoverviewnodesin2hours  dbcitationcountin2hours  \
# count      ...                      63807.000000             63807.000000
# mean       ...                          2.415017                 9.059946
# std        ...                          4.854300                60.370267
# min        ...                          0.000000                 0.000000
# 25%        ...                          0.000000                 0.000000
# 50%        ...                          1.000000                 0.000000
# 75%        ...                          3.000000                 5.000000
# max        ...                        264.000000             13214.000000
#
#        hintsdbcitationcountin2hours  searchdbcitationcountin2hours  \
# count                  63807.000000                   63807.000000
# mean                       6.100005                       2.424060
# std                       20.944900                       6.877242
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        2.000000                       1.000000
# max                      569.000000                     230.000000
#
#        dbcitationnodescountin2hours  dbcitationdatabasecountin2hours  \
# count                  63807.000000                     63807.000000
# mean                       5.517482                         2.332268
# std                       27.453810                         4.477975
# min                        0.000000                         0.000000
# 25%                        0.000000                         0.000000
# 50%                        0.000000                         0.000000
# 75%                        4.000000                         3.000000
# max                     5399.000000                       248.000000
#
#        createnodesfromhintsin2hours  createnodesfromsearchin2hours  \
# count                  63807.000000                   63807.000000
# mean                       2.701271                       1.036093
# std                       12.534133                       4.840295
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        0.000000                       0.000000
# max                      559.000000                     742.000000
#
#        createnodesfromotherin2hours           age
# count                  63807.000000  63807.000000
# mean                       0.613773     21.842259
# std                       73.741663     44.832175
# min                        0.000000  -7983.000000
# 25%                        0.000000     -1.000000
# 50%                        0.000000     21.000000
# 75%                        0.000000     38.000000
# max                    17977.000000   1688.000000
#
# [8 rows x 56 columns]

# %%
df['y']= df.netbillthroughquantity

# %%
#Explore Categorical variable

categorical_variables = ['regtype','signupsubscription','entrypage','device',
                   'firstactivity24houraftersignup','firstactivity2houraftersignup','lastofferpage']

df.entrypage.fillna('Unknown',inplace=True)
df.device.fillna('Unknown',inplace=True)
df.lastofferpage.fillna('Unknown',inplace=True)

for x in np.arange(len(categorical_variables)):
    print 'x:', x, ' feature name: ', categorical_variables[x]
    print df[categorical_variables[x]].value_counts()
    print df.groupby(categorical_variables[x]).y.mean().order(ascending = False)
# Out:
# x: 0  feature name:  regtype
# FT Signup    49137
# Merlin       10510
# Other         4160
# dtype: int64
# regtype
# Merlin       0.533777
# Other        0.489663
# FT Signup    0.382115
# Name: y, dtype: float64
# x: 1  feature name:  signupsubscription
# USDeluxe       53459
# WorldDeluxe    10348
# dtype: int64
# signupsubscription
# USDeluxe              0.419836
# WorldDeluxe           0.384519
# Name: y, dtype: float64
# x: 2  feature name:  entrypage
# Loggged Out HomePage        26543
# Other                       14579
# Secure Stack                 6500
# Marketing Landing Pages      3369
# (null)                       3238
# Search Results               2852
# family facts                 2041
# records                      1277
# Search Forms                 1243
# Merlin                        675
# Logged in HomePage            643
# DNA                           361
# message boards                304
# Trees                         109
# Help/FAQ                       29
# Help and Advice Articles       24
# Online Community Support       20
# dtype: int64
# entrypage
# Trees                       0.577982
# Merlin                      0.534815
# (null)                      0.511736
# message boards              0.500000
# DNA                         0.487535
# records                     0.451840
# Loggged Out HomePage        0.439400
# Search Forms                0.428801
# Help/FAQ                    0.413793
# Search Results              0.411290
# family facts                0.407153
# Marketing Landing Pages     0.402196
# Online Community Support    0.400000
# Other                       0.376295
# Logged in HomePage          0.349922
# Secure Stack                0.329846
# Help and Advice Articles    0.291667
# Name: y, dtype: float64
# x: 3  feature name:  device
# Other             40282
# Mobile Phone      13590
# Tablet             6631
# (null)             3238
# Media Player         54
# Gaming Console       12
# dtype: int64
# device
# (null)            0.511736
# Tablet            0.451214
# Other             0.437789
# Mobile Phone      0.303532
# Media Player      0.222222
# Gaming Console    0.166667
# Name: y, dtype: float64
# x: 4  feature name:  firstactivity24houraftersignup
# Search                          22616
# Create Tree                     15923
# Create Nodes                     9814
# ContentView                      7348
# Signup                           4869
# FamilyView                       1928
# Mod Record Hints                  442
# Pedigree                          353
# Create Citation with DBID         259
# PersonOverview                    196
# Mod Persona Hints                  33
# Create Object                      13
# Mod Object Hints                   11
# Create Citation without DBID        2
# dtype: int64
# firstactivity24houraftersignup
# Mod Object Hints                  0.636364
# PersonOverview                    0.581633
# Mod Persona Hints                 0.545455
# Create Object                     0.538462
# FamilyView                        0.520228
# Mod Record Hints                  0.509050
# ContentView                       0.503266
# Create Citation with DBID         0.501931
# Create Citation without DBID      0.500000
# Pedigree                          0.484419
# Search                            0.412186
# Create Nodes                      0.409211
# Create Tree                       0.405640
# Signup                            0.257137
# Name: y, dtype: float64
# x: 5  feature name:  firstactivity2houraftersignup
# Search                          22616
# Create Tree                     15923
# Create Nodes                     9814
# ContentView                      7348
# Signup                           4869
# FamilyView                       1928
# Mod Record Hints                  442
# Pedigree                          353
# Create Citation with DBID         259
# PersonOverview                    196
# Mod Persona Hints                  33
# Create Object                      13
# Mod Object Hints                   11
# Create Citation without DBID        2
# dtype: int64
# firstactivity2houraftersignup
# Mod Object Hints                 0.636364
# PersonOverview                   0.581633
# Mod Persona Hints                0.545455
# Create Object                    0.538462
# FamilyView                       0.520228
# Mod Record Hints                 0.509050
# ContentView                      0.503266
# Create Citation with DBID        0.501931
# Create Citation without DBID     0.500000
# Pedigree                         0.484419
# Search                           0.412186
# Create Nodes                     0.409211
# Create Tree                      0.405640
# Signup                           0.257137
# Name: y, dtype: float64
# x: 6  feature name:  lastofferpage
# ancestry us : offer : free trial : cms                 29113
# ancestry us : offer : deny : us free trial             19306
# (null)                                                  9478
# ancestry us : offer : free trial : cms radical ftlp     2624
# ancestry us : offer : tablet free trial : cms           2395
# ancestry us : offer : deny : world free trial            605
# ancestry us : offer : hard offer : cms                   110
# ancestry us : offer : compare : default                   94
# ancestry us : secure : my account : home                  65
# ancestry us : offer : dna : home                           9
# ancestry us : offer : mobile hard offer : cms              5
# ancestry us : offer : deny : us hard offer                 3
# dtype: int64
# lastofferpage
# ancestry us : offer : dna : home                       0.888889
# ancestry us : offer : compare : default                0.638298
# ancestry us : offer : mobile hard offer : cms          0.600000
# ancestry us : offer : hard offer : cms                 0.500000
# ancestry us : offer : deny : us free trial             0.481560
# ancestry us : offer : free trial : cms                 0.414969
# ancestry us : secure : my account : home               0.384615
# ancestry us : offer : deny : world free trial          0.381818
# (null)                                                 0.350812
# ancestry us : offer : tablet free trial : cms          0.329019
# ancestry us : offer : free trial : cms radical ftlp    0.209604
# ancestry us : offer : deny : us hard offer             0.000000
# Name: y, dtype: float64

# %%
#encode features 
from sklearn import preprocessing
from sklearn.preprocessing import scale

df_numerical = df.copy()
encoder_dict = {}

for col in categorical_variables:
    le = preprocessing.LabelEncoder()
    le.fit(df[col])
    encoder_dict[col] = le.classes_
    df_numerical[col] = le.transform(df[col])

# df_numerical.head()
# For numerical variables, normalize data and study their covariance.


df_norm = pd.DataFrame(scale(df_numerical.ix[:, 6:]),columns= df_numerical.ix[:, 6:].columns)
# Out:
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\utils\validation.py:498: UserWarning: The scale function assumes floating point values as input, got int64
#   "got %s" % (estimator, X.dtype))
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:145: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   Xr -= mean_
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:153: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:158: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   Xr -= mean_1
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:160: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   Xr /= std_
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:169: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\cwang\AppData\Local\Continuum\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:174: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   Xr -= mean_2

# %%
df_norm.describe()
# Out:
#        firstactivity2houraftersignup  lastofferpage  sessioncount24  \
# count                   63807.000000   63807.000000    63807.000000
# mean                        0.076308       0.041375        0.040121
# std                         0.265493       0.204208        0.265665
# min                         0.000000       0.000000        0.000000
# 25%                         0.000000       0.000000        0.000000
# 50%                         0.000000       0.000000        0.000000
# 75%                         0.000000       0.000000        0.000000
# max                         1.000000       2.000000        6.000000
#
#        sessioncount2hr  firstsessionlength  secondsessionlength  \
# count     63807.000000        63807.000000         63807.000000
# mean          0.003181            0.088000             0.098767
# std           0.057961            0.498735             0.600410
# min           0.000000            0.000000             0.000000
# 25%           0.000000            0.000000             0.000000
# 50%           0.000000            0.000000             0.000000
# 75%           0.000000            0.000000             0.000000
# max           3.000000           12.000000            20.000000
#
#        createtreebeforesignup  searchvolumebeforesignup  \
# count                   63807                     63807
# mean                        0                         0
# std                         0                         0
# min                         0                         0
# 25%                         0                         0
# 50%                         0                         0
# 75%                         0                         0
# max                         0                         0
#
#        contentviewimagebeforesignup  contentviewimagedbbeforesignup  ...    \
# count                  63807.000000                    63807.000000  ...
# mean                       0.021095                        0.000737  ...
# std                        0.852171                        0.055560  ...
# min                        0.000000                        0.000000  ...
# 25%                        0.000000                        0.000000  ...
# 50%                        0.000000                        0.000000  ...
# 75%                        0.000000                        0.000000  ...
# max                      117.000000                        7.000000  ...
#
#        dbcitationcountin2hours  hintsdbcitationcountin2hours  \
# count             63807.000000                  63807.000000
# mean                  0.018713                      0.093093
# std                   0.918365                      0.702816
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.000000
# 50%                   0.000000                      0.000000
# 75%                   0.000000                      0.000000
# max                 217.000000                     25.000000
#
#        searchdbcitationcountin2hours  dbcitationnodescountin2hours  \
# count                   63807.000000                  63807.000000
# mean                        0.083596                      0.033836
# std                         0.628799                      0.873785
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                        31.000000                    195.000000
#
#        dbcitationdatabasecountin2hours  createnodesfromhintsin2hours  \
# count                     63807.000000                  63807.000000
# mean                          0.069287                      0.080508
# std                           0.486032                      0.754153
# min                           0.000000                      0.000000
# 25%                           0.000000                      0.000000
# 50%                           0.000000                      0.000000
# 75%                           0.000000                      0.000000
# max                          53.000000                     43.000000
#
#        createnodesfromsearchin2hours  createnodesfromotherin2hours  \
# count                   63807.000000                  63807.000000
# mean                        0.052502                      0.006614
# std                         0.793353                      0.988724
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                       151.000000                    242.000000
#
#                 age      y
# count  63807.000000  63807
# mean       0.006347      0
# std        0.837074      0
# min     -178.000000      0
# 25%        0.000000      0
# 50%        0.000000      0
# 75%        0.000000      0
# max       36.000000      0
#
# [8 rows x 58 columns]

# %%
#print encoder_dict

# %%
# produce covance matrix 
df_cov = df_norm.cov()
df_cov.to_csv('C:\Users\cwang\Documents\Training\DataScience\Project\CovMatrix.csv')

#Remove columns have high covariance and create dataset at ProjectRawDataCleanUp.csv

# %%
#Get model dataset
X = pd.DataFrame(df_numerical.ix[:, 1:62],columns= df_numerical.ix[:, 1:62].columns)
X_names = df_numerical.ix[:, 1:62].columns
y = df_numerical.y
#X.describe()
#print df_numerical.describe()
#print df_numerical.shape

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, confusion_matrix, roc_curve, auc,
                             accuracy_score, roc_auc_score)
from sklearn.tree import export_graphviz

# %%
# use original dataset to build model
x_axis = []
y_axis = []
for k in range(20)[2:]:
    for j in range(20)[1:]:
        dtc = DecisionTreeClassifier(max_depth=k,min_samples_leaf = len(X)*0.01*j, random_state=1)
        scores = cross_val_score(dtc, X, y, cv=10, scoring='accuracy')
        #print 'For max depth:', k
        x_axis.append(k*100 + j)
        #print 'Decision tree accuracy: {}'.format(np.mean(scores))
        y_axis.append(np.mean(scores))

# %%
#print x_axis
#print y_axis

ig, ax = plt.subplots(1,1)
ax.plot(x_axis, y_axis, color='red', label = 'Decision Tree ')
ax.set_ylabel('Accuracy Rate')
ax.set_xlabel('Max Tree Depth')
ax.legend(loc='upper right',frameon=True)

# %%
print max(y_axis)
print 'Optimal Max Tree Depth:', x_axis[y_axis.index(max(y_axis))]/100, ' and optimal min samples leaf:', x_axis[y_axis.index(max(y_axis))]- x_axis[y_axis.index(max(y_axis))]/100*100, '%'
# Out:
# 0.617722256102
# Optimal Max Tree Depth: 6  and optimal min samples leaf: 1 %

# %%
from sklearn.metrics import accuracy_score

#Chose tree depth of 7 since it generates the best accurate rate
treeclf = DecisionTreeClassifier(max_depth=6, min_samples_leaf = len(X)*0.01, random_state=1)
treeclf.fit(X, y)
y_pred = treeclf.predict(X)

#print confusion matrix
conf_mat = confusion_matrix(y, y_pred)
print(conf_mat )

print classification_report(y, y_pred, target_names=['Not billthrough', 'billthrough'])

#print out top 10 features
pd_features = pd.DataFrame({'feature':X.columns, 'importance':treeclf.feature_importances_}).sort(['importance'], ascending=False)
print pd_features.iloc[:10,]

#calculate true positive rate and false postive rate
y_comb = pd.DataFrame({'y':y, 'y_pred':y_pred }) 

#true positive rate
print 'True Positive Rate:', y_comb[y_comb.y == 1].y_pred.mean()
#false positive rate
print 'False Positive Rate:', y_comb[y_comb.y == 0].y_pred.mean()

print 'Accuracy score:', accuracy_score(y, y_pred)
# Out:
#  [[29874  7510]
#  [16514  9909]]
#                  precision    recall  f1-score   support
#
# Not billthrough       0.64      0.80      0.71     37384
#     billthrough       0.57      0.38      0.45     26423
#
#     avg / total       0.61      0.62      0.61     63807
#
#                             feature  importance
# 27       personahintsgeneratedcount    0.369111
# 0                           regtype    0.188646
# 10              secondsessionlength    0.158229
# 9                firstsessionlength    0.092952
# 6                     lastofferpage    0.050424
# 24   totalpendinghintscountatsignup    0.023864
# 2                         entrypage    0.022584
# 3                            device    0.019654
# 1                signupsubscription    0.017734
# 46  contentimageviewdbcountin2hours    0.014268
# True Positive Rate: 0.375014192181
# False Positive Rate: 0.200888080462
# Accuracy score: 0.623489585782

# %%
def plot_roc_curve(y_test, p_proba):
    # calculates: false positive rate, true positive rate, 
    fpr, tpr, thresholds = roc_curve(y_test, p_proba[:, 1])
    
    roc_auc = auc(fpr, tpr)
    # Plot ROC curve
    plt.plot(fpr, tpr, label= 'AUC = %0.3f' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate or (1 - Specifity)')
    plt.ylabel('True Positive Rate or (Sensitivity)')
    plt.title('ROC')
    plt.legend(loc="lower right")

# %%
#ROC curve
p_proba = treeclf.predict_proba(X)
plot_roc_curve(y, p_proba)

# %%
with open("C:\Users\cwang\Documents\DAT_SF_14\project\image\OnboardingTree.dot", 'wb') as f:
    f = export_graphviz(treeclf, out_file=f, feature_names=X.columns)

# %%
# Visualize the tree at cmd line
# dot -Tpng OnboardingTree.dot -o OnboardingTreeView.png  --or--  dot -Tpng outtree.dot -o treeview.png

# %%
#Get Tree structure and print out leave summary stats into excel
def get_criteria(nodelist):
    #print "Call get_criteria:"
    criteria = ''
    #print nodelist
    for item in nodelist:

        try:
            feature = item[3]
            threshholder = item[2]
            split = item[1]
        except(IndexError):
            continue 

        if split == 'l': splitsymbol = '<='
        if split == 'r': splitsymbol = '>'
        node_crit = '(df[\'' + feature + '\'] ' + splitsymbol + ' ' + str(threshholder) + ') & '
        criteria += node_crit
    #print "get_criteria return:", criteria
    return criteria[:-3]

def get_lineage(tree, feature_names):
    left      = tree.tree_.children_left
    right     = tree.tree_.children_right
    threshold = tree.tree_.threshold
    features  = [feature_names[i] for i in tree.tree_.feature]
    #print "Features:", features

    # get ids of child nodes
    idx = np.argwhere(left == -1)[:,0]     

    def recurse(left, right, child, lineage=None):          
        if lineage is None:
            lineage = [child]
        if child in left:
            parent = np.where(left == child)[0].item()
            split = 'l'
        else:
            parent = np.where(right == child)[0].item()
            split = 'r'

        lineage.append([parent, split, threshold[parent], features[parent]])

        if parent == 0:
            lineage.reverse()
            return lineage
        else:
            return recurse(left, right, parent, lineage)

    return_criteria = []

    for child in idx:
        nodelist = []
        for node in recurse(left, right, child):
            #print node
            nodelist.append(node)
        #print nodelist

        criteria = get_criteria(nodelist)
        #print criteria
        return_criteria.append(criteria)
    
    return return_criteria

# %%
# df is the dataframe with target variable
def leaf_pct(criteria, df):

    outleaf = open('C:\Users\cwang\Documents\DAT_SF_14\project\image\billthrough_leaf_stats.txt', 'w')

    outleaf.write('\t'.join(['Conditions', 'BTR', 'Leaf Size']))
    outleaf.write('\n')

    for conditions in criteria:
        
        code = 'subdf = df[' + conditions + ']'
        exec(code)

        outleaf.write('\t'.join([conditions, str(subdf['y'].mean()), str(subdf['y'].count())]))
        outleaf.write('\n')

# %%
#execute function to get leaf stats
criteria = get_lineage(treeclf, X_names)
leaf_pct(criteria, df_numerical)

# %%
# From Decision Tree above, we discovered that hint generation is No.1 driver.
# Question: What drives hint generation?\
# Please go to ipython notebook - CourseProject_Cindy-HintGeneration-ResolveUnbalanceDataset
